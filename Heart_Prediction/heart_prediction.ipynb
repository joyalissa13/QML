# %% [markdown]
# # Heart Prediction
#
# [\![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/joyalissa13/QML/blob/main/Heart_Prediction/quickstart_colab.ipynb)

# %% [markdown]
# ## Build a Quantum ML Classifier
#
# Create a small quantum machine learning model that predicts whether a patient has heart disease based on the tabular dataset in this notebook. Your task is to design a simple Quantum ML pipeline: choose a quantum feature embedding for the classical inputs, build a variational circuit with trainable parameters, define a training objective, and fit the model on the provided data.
#
# Try to report the final accuracy and discuss whether changing the embedding strategy or ansatz depth improves the result.

# %%
# %pip install -q pandas

# %%
import os
from pathlib import Path

REPO_ROOT = '/content/QML'
if not os.path.exists(REPO_ROOT):
    \!git clone https://github.com/joyalissa13/QML.git /content/QML

os.chdir(REPO_ROOT)
print('Working directory:', os.getcwd())

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path('/content/QML/Heart_Prediction/Heart Prediction Quantum Dataset.csv')
df = pd.read_csv(DATA_PATH)

print(df.head())
print('\nShape:', df.shape)
print('\nColumns:', df.columns.tolist())
