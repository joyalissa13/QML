# %% [markdown]
# # Breast Cancer Wisconsin
#
# [\![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/joyalissa13/QML/blob/main/Breast_Cancer_Wisconsin/quickstart_colab.ipynb)

# %%
# %pip install -q pandas

# %% [markdown]
# Create a small quantum machine learning model that predicts whether a breast cancer sample is benign or malignant. Your task is to design a simple Quantum ML pipeline: choose a way to encode the tabular features into a quantum circuit, build a variational ansatz with trainable parameters, define a loss function, and train the model on the dataset provided in this notebook.
#
# Try to evaluate your model with an accuracy metric and briefly reflect on which features, embedding choice, or circuit depth seem to work best.

# %%
import os
from pathlib import Path

REPO_ROOT = '/content/QML'
if not os.path.exists(REPO_ROOT):
    \!git clone https://github.com/joyalissa13/QML.git /content/QML

os.chdir(REPO_ROOT)
print('Working directory:', os.getcwd())

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path('/content/QML/Breast_Cancer_Wisconsin/data.csv')
df = pd.read_csv(DATA_PATH)

print(df.head())
print('\nShape:', df.shape)
print('\nColumns:', df.columns.tolist())
